# %%
# !rm sequicity/ -r
# !git clone https://github.com/dehanalkautsar/sequicity.git
# !cd sequicity

# %% [markdown]
# ### Before running

# %%
# Install required python packages.
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nltk: filename=nltk-3.2.1-py3-none-any.whl size=1316655 sha256=b9ae77c73c49981eb37e648abdcc710e3bf1358d646c7c1697b7f4b7802eb4f4
#   Stored in directory: /root/.cache/pip/wheels/5d/cd/92/19469089f548713316c7e451ab83c70d82951fb8a288855244
# Successfully built nltk
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# ...

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Make directories under PROJECT_ROOT
# !rm vocab -r
# !rm results -r
# !rm models -r

# !mkdir vocab
# !mkdir log
# !mkdir results
# !mkdir models
# !mkdir sheets

# %%
# Download pretrained fastText word vectors and place them in PROJECT_ROOT/data/fastText.

## fastText
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.id.300.vec.gz # indo vec
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.vec.gz # eng vec
# !wget https://dl.fbaipublicfiles.com/arrival/vectors/wiki.multi.id.vec # bilingual en-id vec
# Out:
# --2023-02-11 10:55:28--  https://dl.fbaipublicfiles.com/arrival/vectors/wiki.multi.id.vec
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 628830254 (600M) [text/plain]
# Saving to: ‘wiki.multi.id.vec’
#
# wiki.multi.id.vec   100%[===================>] 599.70M  82.6MB/s    in 7.4s
#
# 2023-02-11 10:55:36 (80.8 MB/s) - ‘wiki.multi.id.vec’ saved [628830254/628830254]

# %%
## fastText indo
# !gunzip "cc.id.300.vec.gz"
# !mkdir "data/fasttext"
# !mv "cc.id.300.vec" "data/fasttext"

## fastText eng
# !gunzip "cc.en.300.vec.gz"
# !mv "cc.en.300.vec" "data/fasttext"

## fastText x-lingual & bilingual
# !mv "wiki.multi.id.vec" "data/fasttext"

# %% [markdown]
# ### Training

# %%
import pathlib

pathlib.Path('log').mkdir(parents=True, exist_ok=True)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# %cd ..
# !unzip "root/nltk_data/corpora/omw-1.4.zip" -d "root/nltk_data/corpora/"
# !unzip "root/nltk_data/corpora/wordnet.zip" -d "root/nltk_data/corpora/"
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# /
# Archive:  root/nltk_data/corpora/omw-1.4.zip
#    creating: root/nltk_data/corpora/omw-1.4/
#    creating: root/nltk_data/corpora/omw-1.4/fin/
#   inflating: root/nltk_data/corpora/omw-1.4/fin/LICENSE
#   inflating: root/nltk_data/corpora/omw-1.4/fin/citation.bib
#   inflating: root/nltk_data/corpora/omw-1.4/fin/wn-data-fin.tab
#    creating: root/nltk_data/corpora/omw-1.4/heb/
#   inflating: root/nltk_data/corpora/omw-1.4/heb/LICENSE
#   inflating: root/nltk_data/corpora/omw-1.4/heb/citation.bib
#   inflating: root/nltk_data/corpora/omw-1.4/heb/README
#   inflating: root/nltk_data/corpora/omw-1.4/heb/wn-data-heb.tab
# ...

# %%
# %cd content/sequicity
# %cd ..
# Out:
# /content/sequicity

# %% [markdown]
# #### CamRest

# %% [markdown]
# ##### Baseline: English

# %%
# train: english
# !python model.py -mode train -model tsdf-camrest -exp_setting en
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# seed : 0
# vocab_size : 800
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# data : ./data/CamRest676/CamRest/CamRest676.json
# entity : ./data/CamRest676/CamRest/CamRestOTGY.json
# db : ./data/CamRest676/CamRest/CamRestDB.json
# fasttext_path : ./data/fasttext/cc.en.300.vec
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# beam_size : 10
# sampling : False
# ...

# %%
# test: english
# !python model.py -mode test -model tsdf-camrest
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# seed : 0
# vocab_size : 800
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# data : ./data/CamRest676/CamRest/CamRest676.json
# entity : ./data/CamRest676/CamRest/CamRestOTGY.json
# db : ./data/CamRest676/CamRest/CamRestDB.json
# fasttext_path : ./data/fasttext/cc.en.300.vec
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# beam_size : 10
# sampling : False
# ...

# %% [markdown]
# ##### Experiment Settings: Indonesian

# %%
# train: indonesian
# !python model.py -mode train -model tsdf-camrest
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# seed : 0
# vocab_size : 800
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# data : ./data/CamRest676/IndoCamRest/IndoCamRest676.json
# entity : ./data/CamRest676/IndoCamRest/ontology_indo.json
# db : ./data/CamRest676/IndoCamRest/KB_indo.json
# fasttext_path : ./data/fasttext/cc.id.300.vec
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# beam_size : 10
# ...

# %%
# test: indonesian
# !python model.py -mode test -model tsdf-camrest
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# seed : 0
# vocab_size : 800
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# data : ./data/CamRest676/IndoCamRest/IndoCamRest676.json
# entity : ./data/CamRest676/IndoCamRest/ontology_indo.json
# db : ./data/CamRest676/IndoCamRest/KB_indo.json
# fasttext_path : ./data/fasttext/cc.id.300.vec
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# beam_size : 10
# ...

# %% [markdown]
# ##### Zero-shot Cross-lingual En-Id

# %%
#### train: x-ling en-id
# !python model.py -mode train -model tsdf-camrest -exp_setting cross
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# exp_setting : cross
# seed : 0
# vocab_size : 1600
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# vocab_data_path : ./data/CamRest676/bi/IndoCamRest676_bi.json
# vocab_db_path : ./data/CamRest676/bi/kb_indo_bi.json
# data : ./data/CamRest676/CamRest/CamRest676.json
# entity : ./data/CamRest676/CamRest/CamRestOTGY.json
# ...

# %%
#### test: x-ling en-id
# !python model.py -mode test -model tsdf-camrest -exp_setting cross
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# exp_setting : cross
# seed : 0
# vocab_size : 1600
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# vocab_data_path : ./data/CamRest676/bi/IndoCamRest676_bi.json
# vocab_db_path : ./data/CamRest676/bi/kb_indo_bi.json
# data : ./data/CamRest676/IndoCamRest/IndoCamRest676.json
# entity : ./data/CamRest676/IndoCamRest/ontology_indo.json
# ...

# %% [markdown]
# ##### Bilingual id-en

# %%
#### train: bilingual en-id
# !python model.py -mode train -model tsdf-camrest
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# exp_setting : None
# seed : 0
# vocab_size : 1600
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# data : ./data/CamRest676/bi/IndoCamRest676_bi.json
# entity : ./data/CamRest676/bi/ontology_indo_bi.json
# db : ./data/CamRest676/bi/kb_indo_bi.json
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# ...

# %% [markdown]
# ###### test set bilingual: en v id

# %%
#### test: bilingual en-id : en v id
# !python model.py -mode test -model tsdf-camrest
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# exp_setting : None
# seed : 0
# vocab_size : 1600
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# data : ./data/CamRest676/bi/IndoCamRest676_bi.json
# entity : ./data/CamRest676/bi/ontology_indo_bi.json
# db : ./data/CamRest676/bi/kb_indo_bi.json
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# ...

# %% [markdown]
# ###### test set bilingual: en

# %%
#### test: bilingual en-id : en
# !python model.py -mode test -model tsdf-camrest -exp_setting bi-en
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# exp_setting : bi-en
# seed : 0
# vocab_size : 1600
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# data : ./data/CamRest676/bi/IndoCamRest676_bi.json
# entity : ./data/CamRest676/bi/ontology_indo_bi.json
# db : ./data/CamRest676/bi/kb_indo_bi.json
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# ...

# %% [markdown]
# ###### test set bilingual: id

# %%
#### test: bilingual en-id : id
# !python model.py -mode test -model tsdf-camrest -exp_setting bi-id
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.5
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : camrest
# exp_setting : bi-id
# seed : 0
# vocab_size : 1600
# embedding_size : 300
# hidden_size : 50
# split : (3, 1, 1)
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-camrest.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# data : ./data/CamRest676/bi/IndoCamRest676_bi.json
# entity : ./data/CamRest676/bi/ontology_indo_bi.json
# db : ./data/CamRest676/bi/kb_indo_bi.json
# batch_size : 32
# z_length : 8
# degree_size : 5
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 1
# cuda : False
# spv_proportion : 100
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/camrest.pkl
# result_path : ./results/camrest-rl.csv
# teacher_force : 100
# beam_search : False
# ...

# %% [markdown]
# #### KVRET

# %% [markdown]
# ##### Baseline: English

# %%
# train: english
# !python model.py -mode train -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# seed : 0
# intent : all
# vocab_size : 1400
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/cc.en.300.vec
# train : ./data/kvret/smd/kvret_train_public.json
# dev : ./data/kvret/smd/kvret_dev_public.json
# test : ./data/kvret/smd/kvret_test_public.json
# entity : ./data/kvret/smd/kvret_entities.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# teacher_force : 100
# ...

# %%
# test: english
# !python model.py -mode test -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# seed : 0
# intent : all
# vocab_size : 1400
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/cc.en.300.vec
# train : ./data/kvret/smd/kvret_train_public.json
# dev : ./data/kvret/smd/kvret_dev_public.json
# test : ./data/kvret/smd/kvret_test_public.json
# entity : ./data/kvret/smd/kvret_entities.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# teacher_force : 100
# ...

# %% [markdown]
# ##### Experiment settings: Indonesian

# %%
# train: indonesian
# !python model.py -mode train -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# seed : 0
# intent : all
# vocab_size : 1400
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/cc.id.300.vec
# train : ./data/kvret/indosmd/IndoSMD_train.json
# dev : ./data/kvret/indosmd/IndoSMD_dev.json
# test : ./data/kvret/indosmd/IndoSMD_test.json
# entity : ./data/kvret/indosmd/kvret_indo_entities.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# ...

# %%
# test: indonesian
# !python model.py -mode test -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# seed : 0
# intent : all
# vocab_size : 1400
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/cc.id.300.vec
# train : ./data/kvret/indosmd/IndoSMD_train.json
# dev : ./data/kvret/indosmd/IndoSMD_dev.json
# test : ./data/kvret/indosmd/IndoSMD_test.json
# entity : ./data/kvret/indosmd/kvret_indo_entities.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# ...

# %% [markdown]
# ##### Cross-lingual en-id

# %%
# train: cross lingual en-id
# !python model.py -mode train -model tsdf-kvret -exp_setting cross
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# exp_setting : cross
# seed : 0
# intent : all
# vocab_size : 1800
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# train : ./data/kvret/smd/kvret_train_public.json
# test : ./data/kvret/smd/kvret_test_public.json
# dev : ./data/kvret/indosmd/IndoSMD_test.json
# entity : ./data/kvret/bi/kvret_indo_entities_bi.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# ...

# %%
# train: cross lingual en-id
# !python model.py -mode test -model tsdf-kvret -exp_setting cross
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# exp_setting : cross
# seed : 0
# intent : all
# vocab_size : 1800
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# entity : ./data/kvret/bi/kvret_indo_entities_bi.json
# train : ./data/kvret/indosmd/IndoSMD_train.json
# dev : ./data/kvret/indosmd/IndoSMD_dev.json
# test : ./data/kvret/indosmd/IndoSMD_test.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# ...

# %% [markdown]
# ##### Bilingual en-id

# %%
# train: bilingual en-id
# !python model.py -mode train -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# exp_setting : None
# seed : 0
# intent : all
# vocab_size : 1800
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# train : ./data/kvret/bi/IndoSMD_train_bi.json
# dev : ./data/kvret/bi/IndoSMD_dev_bi.json
# entity : ./data/kvret/bi/kvret_indo_entities_bi.json
# test : ./data/kvret/bi/IndoSMD_test_bi.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# ...

# %% [markdown]
# ###### test bilingual: en v id

# %%
# test: bilingual en-id: en v id
# !python model.py -mode test -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# seed : 0
# intent : all
# vocab_size : 1400
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# train : ./data/kvret/bi/IndoSMD_train_bi.json
# dev : ./data/kvret/bi/IndoSMD_dev_bi.json
# test : ./data/kvret/bi/IndoSMD_test_bi.json
# entity : ./data/kvret/bi/kvret_indo_entities_bi.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# teacher_force : 100
# ...

# %% [markdown]
# ###### test bilingual: id

# %%
# test: bilingual en-id: id
# !python model.py -mode test -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# exp_setting : None
# seed : 0
# intent : all
# vocab_size : 1800
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# train : ./data/kvret/bi/IndoSMD_train_bi.json
# dev : ./data/kvret/bi/IndoSMD_dev_bi.json
# entity : ./data/kvret/bi/kvret_indo_entities_bi.json
# test : ./data/kvret/indosmd/IndoSMD_test.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# ...

# %% [markdown]
# ###### test bilingual: en

# %%
# test: bilingual en-id: en
# !python model.py -mode test -model tsdf-kvret
# Out:
# INFO:summarizer.preprocessing.cleaner:'pattern' package not found; tag filters are not available for English
# INFO:root:cuda_device : 0
# eos_m_token : EOS_M
# beam_len_bonus : 0.6
# mode : unknown
# m : TSD
# prev_z_method : separate
# dataset : kvret
# exp_setting : None
# seed : 0
# intent : all
# vocab_size : 1800
# embedding_size : 300
# hidden_size : 50
# split : None
# lr : 0.003
# lr_decay : 0.5
# vocab_path : ./vocab/vocab-kvret.pkl
# fasttext_path : ./data/fasttext/wiki.multi.id.vec
# train : ./data/kvret/bi/IndoSMD_train_bi.json
# dev : ./data/kvret/bi/IndoSMD_dev_bi.json
# entity : ./data/kvret/bi/kvret_indo_entities_bi.json
# test : ./data/kvret/smd/kvret_test_public.json
# batch_size : 32
# degree_size : 5
# z_length : 8
# layer_num : 1
# dropout_rate : 0.5
# epoch_num : 100
# rl_epoch_num : 2
# cuda : False
# spv_proportion : 100
# alpha : 0.0
# max_ts : 40
# early_stop_count : 3
# new_vocab : True
# model_path : ./models/kvret.pkl
# result_path : ./results/kvret.csv
# ...

# %% [markdown]
# ## To DO
#
# - change GloVe to fastText ✓
# - test to experiment settings
